# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform (low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform (low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data. 
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

#Create Counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather['sys']['country']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                    
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | vao
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | lamu
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | kodinsk
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | daru
# Processing Record 8 of Set 1 | collie
# Processing Record 9 of Set 1 | port hedland
# Processing Record 10 of Set 1 | reitz
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | ponta do sol
# Processing Record 17 of Set 1 | hailar
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | hirara
# Processing Record 21 of Set 1 | ketchikan
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | leshukonskoye
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | port hueneme
# Processing Record 26 of Set 1 | maungatapere
# Processing Record 27 of Set 1 | alyangula
# Processing Record 28 of Set 1 | buala
# Processing Record 29 of Set 1 | almaznyy
# Processing Record 30 of Set 1 | songjianghe
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | east london
# Processing Record 33 of Set 1 | isangel
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | banda aceh
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | sola
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | tomatlan
# Processing Record 41 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 1 | komatipoort
# Processing Record 43 of Set 1 | namatanai
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | sur
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | beringovskiy
# Processing Record 1 of Set 2 | reidsville
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | barra do corda
# Processing Record 4 of Set 2 | kaitangata
# Processing Record 5 of Set 2 | cherskiy
# Processing Record 6 of Set 2 | abapo
# Processing Record 7 of Set 2 | mucurapo
# Processing Record 8 of Set 2 | mayo
# Processing Record 9 of Set 2 | rutland
# Processing Record 10 of Set 2 | coahuayana
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | torbay
# Processing Record 14 of Set 2 | katherine
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | sitka
# Processing Record 17 of Set 2 | russell
# Processing Record 18 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 2 | wells
# Processing Record 20 of Set 2 | lagoa
# Processing Record 21 of Set 2 | esil
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | ilhabela
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | korla
# Processing Record 26 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | svetlaya
# Processing Record 29 of Set 2 | vrede
# Processing Record 30 of Set 2 | mackenzie
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 33 of Set 2 | hals
# Processing Record 34 of Set 2 | fortuna
# Processing Record 35 of Set 2 | moron
# Processing Record 36 of Set 2 | lata
# Processing Record 37 of Set 2 | nelson
# Processing Record 38 of Set 2 | puerto ayora
# Processing Record 39 of Set 2 | nikolskoye
# Processing Record 40 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 2 | kahului
# Processing Record 42 of Set 2 | pisco
# Processing Record 43 of Set 2 | quatre cocos
# Processing Record 44 of Set 2 | half moon bay
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | nabire
# Processing Record 47 of Set 2 | elizabeth city
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | tanabe
# Processing Record 50 of Set 2 | severo-kurilsk
# Processing Record 1 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | cidreira
# Processing Record 4 of Set 3 | vila franca do campo
# Processing Record 5 of Set 3 | pilar
# Processing Record 6 of Set 3 | ixtapa
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | warud
# Processing Record 9 of Set 3 | zhigansk
# Processing Record 10 of Set 3 | lucapa
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | bambanglipuro
# Processing Record 13 of Set 3 | hualmay
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | qaanaaq
# Processing Record 16 of Set 3 | baoying
# Processing Record 17 of Set 3 | vila velha
# Processing Record 18 of Set 3 | la ronge
# Processing Record 19 of Set 3 | jinxiang
# Processing Record 20 of Set 3 | kavieng
# Processing Record 21 of Set 3 | samarai
# Processing Record 22 of Set 3 | shingu
# Processing Record 23 of Set 3 | pelym
# Processing Record 24 of Set 3 | bang lamung
# Processing Record 25 of Set 3 | tawang
# Processing Record 26 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 27 of Set 3 | vardo
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | bilibino
# Processing Record 30 of Set 3 | zamora
# Processing Record 31 of Set 3 | hay river
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | kushmurun
# Processing Record 34 of Set 3 | torrington
# Processing Record 35 of Set 3 | ahipara
# Processing Record 36 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 3 | zholymbet
# Processing Record 38 of Set 3 | atar
# Processing Record 39 of Set 3 | boueni
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | hobart
# Processing Record 42 of Set 3 | mbanza-ngungu
# Processing Record 43 of Set 3 | sompeta
# Processing Record 44 of Set 3 | otofuke
# Processing Record 45 of Set 3 | shenjiamen
# Processing Record 46 of Set 3 | san isidro
# Processing Record 47 of Set 3 | bengkulu
# Processing Record 48 of Set 3 | luderitz
# Processing Record 49 of Set 3 | norman wells
# Processing Record 50 of Set 3 | saint-joseph
# Processing Record 1 of Set 4 | lucea
# Processing Record 2 of Set 4 | kozlovo
# Processing Record 3 of Set 4 | jamestown
# Processing Record 4 of Set 4 | high level
# Processing Record 5 of Set 4 | hilo
# Processing Record 6 of Set 4 | hambantota
# Processing Record 7 of Set 4 | mareeba
# Processing Record 8 of Set 4 | pokrovskoye
# Processing Record 9 of Set 4 | yulara
# Processing Record 10 of Set 4 | cabo san lucas
# Processing Record 11 of Set 4 | roald
# Processing Record 12 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 4 | butaritari
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | chichimila
# Processing Record 16 of Set 4 | port lincoln
# Processing Record 17 of Set 4 | khatanga
# Processing Record 18 of Set 4 | qasigiannguit
# Processing Record 19 of Set 4 | burnie
# Processing Record 20 of Set 4 | cedar city
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | emba
# Processing Record 23 of Set 4 | ahuimanu
# Processing Record 24 of Set 4 | zabaykalsk
# Processing Record 25 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 4 | nizhniy lomov
# Processing Record 27 of Set 4 | bambous virieux
# Processing Record 28 of Set 4 | chuy
# Processing Record 29 of Set 4 | yantal
# Processing Record 30 of Set 4 | lubyany
# Processing Record 31 of Set 4 | barwadih
# Processing Record 32 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 4 | cape town
# Processing Record 34 of Set 4 | price
# Processing Record 35 of Set 4 | lompoc
# Processing Record 36 of Set 4 | mount gambier
# Processing Record 37 of Set 4 | bonavista
# Processing Record 38 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 4 | hasaki
# Processing Record 40 of Set 4 | bassar
# Processing Record 41 of Set 4 | honiara
# Processing Record 42 of Set 4 | chapais
# Processing Record 43 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 4 | carandai
# Processing Record 45 of Set 4 | cocorit
# Processing Record 46 of Set 4 | awbari
# Processing Record 47 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 4 | elko
# Processing Record 49 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 4 | nanortalik
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | tongren
# Processing Record 3 of Set 5 | portree
# Processing Record 4 of Set 5 | saint-leu
# Processing Record 5 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 5 | sakakah
# Processing Record 7 of Set 5 | dingle
# Processing Record 8 of Set 5 | victoria
# Processing Record 9 of Set 5 | esperance
# Processing Record 10 of Set 5 | mehamn
# Processing Record 11 of Set 5 | leningradskiy
# Processing Record 12 of Set 5 | vieste
# Processing Record 13 of Set 5 | georgetown
# Processing Record 14 of Set 5 | manthani
# Processing Record 15 of Set 5 | sabang
# Processing Record 16 of Set 5 | berlevag
# Processing Record 17 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 5 | matsusaka
# Processing Record 19 of Set 5 | the valley
# Processing Record 20 of Set 5 | kendal
# Processing Record 21 of Set 5 | sijunjung
# Processing Record 22 of Set 5 | ibra
# Processing Record 23 of Set 5 | margate
# Processing Record 24 of Set 5 | litovko
# Processing Record 25 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 5 | taoudenni
# Processing Record 27 of Set 5 | saint-denis
# Processing Record 28 of Set 5 | mitsamiouli
# Processing Record 29 of Set 5 | bethel
# Processing Record 30 of Set 5 | muereasca
# Processing Record 31 of Set 5 | perth
# Processing Record 32 of Set 5 | bolkhov
# Processing Record 33 of Set 5 | miri
# Processing Record 34 of Set 5 | sao miguel do araguaia
# Processing Record 35 of Set 5 | alofi
# Processing Record 36 of Set 5 | kapit
# Processing Record 37 of Set 5 | nouadhibou
# Processing Record 38 of Set 5 | nzerekore
# Processing Record 39 of Set 5 | churapcha
# Processing Record 40 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 41 of Set 5 | ambon
# Processing Record 42 of Set 5 | tuatapere
# Processing Record 43 of Set 5 | muroto
# Processing Record 44 of Set 5 | taltal
# Processing Record 45 of Set 5 | malangali
# Processing Record 46 of Set 5 | alekseyevsk
# Processing Record 47 of Set 5 | freeport
# Processing Record 48 of Set 5 | tabou
# Processing Record 49 of Set 5 | hohhot
# Processing Record 50 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 1 of Set 6 | manaus
# Processing Record 2 of Set 6 | port augusta
# Processing Record 3 of Set 6 | narsaq
# Processing Record 4 of Set 6 | mayumba
# Processing Record 5 of Set 6 | saint-pierre
# Processing Record 6 of Set 6 | gigmoto
# Processing Record 7 of Set 6 | kenai
# Processing Record 8 of Set 6 | chastyye
# Processing Record 9 of Set 6 | sao filipe
# Processing Record 10 of Set 6 | caravelas
# Processing Record 11 of Set 6 | balabac
# Processing Record 12 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 13 of Set 6 | ancud
# Processing Record 14 of Set 6 | channel-port aux basques
# Processing Record 15 of Set 6 | cuamba
# Processing Record 16 of Set 6 | kihei
# Processing Record 17 of Set 6 | piacabucu
# Processing Record 18 of Set 6 | mount isa
# Processing Record 19 of Set 6 | estelle
# Processing Record 20 of Set 6 | vanimo
# Processing Record 21 of Set 6 | yangambi
# Processing Record 22 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 23 of Set 6 | bubaque
# Processing Record 24 of Set 6 | pevek
# Processing Record 25 of Set 6 | inhambane
# Processing Record 26 of Set 6 | kangaatsiaq
# Processing Record 27 of Set 6 | skoghall
# Processing Record 28 of Set 6 | arlit
# Processing Record 29 of Set 6 | prince rupert
# Processing Record 30 of Set 6 | livingston
# Processing Record 31 of Set 6 | gumdag
# Processing Record 32 of Set 6 | dhidhdhoo
# Processing Record 33 of Set 6 | gold coast
# Processing Record 34 of Set 6 | luena
# Processing Record 35 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 6 | alto araguaia
# Processing Record 37 of Set 6 | shalyhyne
# Processing Record 38 of Set 6 | brainerd
# Processing Record 39 of Set 6 | rio gallegos
# Processing Record 40 of Set 6 | mamallapuram
# Processing Record 41 of Set 6 | celestun
# Processing Record 42 of Set 6 | adrar
# Processing Record 43 of Set 6 | terrasini
# Processing Record 44 of Set 6 | grand bank
# Processing Record 45 of Set 6 | poole
# Processing Record 46 of Set 6 | portales
# Processing Record 47 of Set 6 | komsomolskiy
# Processing Record 48 of Set 6 | alenquer
# Processing Record 49 of Set 6 | vostok
# Processing Record 50 of Set 6 | lorengau
# Processing Record 1 of Set 7 | samoylovka
# Processing Record 2 of Set 7 | dzaoudzi
# Processing Record 3 of Set 7 | vila
# Processing Record 4 of Set 7 | marawi
# Processing Record 5 of Set 7 | auki
# Processing Record 6 of Set 7 | faanui
# Processing Record 7 of Set 7 | flinders
# Processing Record 8 of Set 7 | camacha
# Processing Record 9 of Set 7 | haines junction
# Processing Record 10 of Set 7 | chokurdakh
# Processing Record 11 of Set 7 | viedma
# Processing Record 12 of Set 7 | cairns
# Processing Record 13 of Set 7 | martapura
# Processing Record 14 of Set 7 | lalomanu
# City not found. Skipping...
# Processing Record 15 of Set 7 | virginia beach
# Processing Record 16 of Set 7 | mishelevka
# Processing Record 17 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 7 | alice springs
# Processing Record 19 of Set 7 | dalvik
# Processing Record 20 of Set 7 | waingapu
# Processing Record 21 of Set 7 | mizdah
# Processing Record 22 of Set 7 | kiama
# Processing Record 23 of Set 7 | kruisfontein
# Processing Record 24 of Set 7 | saint george
# Processing Record 25 of Set 7 | praia da vitoria
# Processing Record 26 of Set 7 | dunedin
# Processing Record 27 of Set 7 | la plata
# Processing Record 28 of Set 7 | souillac
# Processing Record 29 of Set 7 | gambela
# Processing Record 30 of Set 7 | wilmington
# Processing Record 31 of Set 7 | kahramanmaras
# Processing Record 32 of Set 7 | minab
# Processing Record 33 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 7 | port moresby
# Processing Record 35 of Set 7 | baker city
# Processing Record 36 of Set 7 | katangli
# Processing Record 37 of Set 7 | moyale
# Processing Record 38 of Set 7 | juba
# Processing Record 39 of Set 7 | rawson
# Processing Record 40 of Set 7 | clyde river
# Processing Record 41 of Set 7 | ruwi
# Processing Record 42 of Set 7 | la paz
# Processing Record 43 of Set 7 | yilan
# Processing Record 44 of Set 7 | sangar
# Processing Record 45 of Set 7 | nome
# Processing Record 46 of Set 7 | bathsheba
# Processing Record 47 of Set 7 | byron bay
# Processing Record 48 of Set 7 | roma
# Processing Record 49 of Set 7 | college
# Processing Record 50 of Set 7 | lanzhou
# Processing Record 1 of Set 8 | sao joao da barra
# Processing Record 2 of Set 8 | lahore
# Processing Record 3 of Set 8 | kaeo
# Processing Record 4 of Set 8 | tevaitoa
# Processing Record 5 of Set 8 | svetlyy
# Processing Record 6 of Set 8 | colonial park
# Processing Record 7 of Set 8 | tuy hoa
# Processing Record 8 of Set 8 | port hardy
# Processing Record 9 of Set 8 | bay roberts
# Processing Record 10 of Set 8 | grindavik
# Processing Record 11 of Set 8 | fredericksburg
# Processing Record 12 of Set 8 | poienari
# Processing Record 13 of Set 8 | raga
# Processing Record 14 of Set 8 | manado
# Processing Record 15 of Set 8 | chumikan
# Processing Record 16 of Set 8 | ibipeba
# Processing Record 17 of Set 8 | aksu
# Processing Record 18 of Set 8 | austintown
# Processing Record 19 of Set 8 | yala
# Processing Record 20 of Set 8 | trincomalee
# Processing Record 21 of Set 8 | salalah
# Processing Record 22 of Set 8 | kamenka
# Processing Record 23 of Set 8 | baracoa
# Processing Record 24 of Set 8 | san juan de colon
# Processing Record 25 of Set 8 | irece
# Processing Record 26 of Set 8 | batagay-alyta
# Processing Record 27 of Set 8 | abbeville
# Processing Record 28 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 8 | laureles
# Processing Record 30 of Set 8 | banfora
# Processing Record 31 of Set 8 | gulmarg
# Processing Record 32 of Set 8 | visby
# Processing Record 33 of Set 8 | fomboni
# Processing Record 34 of Set 8 | laguna
# Processing Record 35 of Set 8 | ambilobe
# Processing Record 36 of Set 8 | tabuk
# Processing Record 37 of Set 8 | geraldton
# Processing Record 38 of Set 8 | nelson bay
# Processing Record 39 of Set 8 | marsabit
# Processing Record 40 of Set 8 | safaga
# Processing Record 41 of Set 8 | iskateley
# Processing Record 42 of Set 8 | lethem
# Processing Record 43 of Set 8 | prado
# Processing Record 44 of Set 8 | saint-louis
# Processing Record 45 of Set 8 | pimenta bueno
# Processing Record 46 of Set 8 | erenhot
# Processing Record 47 of Set 8 | singkang
# Processing Record 48 of Set 8 | ubajara
# Processing Record 49 of Set 8 | derzhavinsk
# Processing Record 50 of Set 8 | krasnoselkup
# Processing Record 1 of Set 9 | taiyuan
# Processing Record 2 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 9 | goderich
# Processing Record 4 of Set 9 | ayan
# Processing Record 5 of Set 9 | maple creek
# Processing Record 6 of Set 9 | shimoda
# Processing Record 7 of Set 9 | manturovo
# Processing Record 8 of Set 9 | vada
# Processing Record 9 of Set 9 | saldanha
# Processing Record 10 of Set 9 | mbalmayo
# Processing Record 11 of Set 9 | whithorn
# Processing Record 12 of Set 9 | valparaiso
# Processing Record 13 of Set 9 | trairi
# Processing Record 14 of Set 9 | plettenberg bay
# Processing Record 15 of Set 9 | hearst
# Processing Record 16 of Set 9 | marysville
# Processing Record 17 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 18 of Set 9 | buraydah
# Processing Record 19 of Set 9 | sao francisco
# Processing Record 20 of Set 9 | mangrol
# Processing Record 21 of Set 9 | mataram
# Processing Record 22 of Set 9 | desaguadero
# Processing Record 23 of Set 9 | axim
# Processing Record 24 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 9 | kimbe
# Processing Record 26 of Set 9 | kalmunai
# Processing Record 27 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 9 | marshall
# Processing Record 29 of Set 9 | xinxiang
# Processing Record 30 of Set 9 | basirpur
# Processing Record 31 of Set 9 | taksimo
# Processing Record 32 of Set 9 | port-cartier
# Processing Record 33 of Set 9 | pyapon
# Processing Record 34 of Set 9 | usinsk
# Processing Record 35 of Set 9 | pandan
# Processing Record 36 of Set 9 | pimentel
# Processing Record 37 of Set 9 | paamiut
# Processing Record 38 of Set 9 | griffith
# Processing Record 39 of Set 9 | mzimba
# Processing Record 40 of Set 9 | srandakan
# Processing Record 41 of Set 9 | airai
# Processing Record 42 of Set 9 | camana
# Processing Record 43 of Set 9 | dinajpur
# Processing Record 44 of Set 9 | ilebo
# Processing Record 45 of Set 9 | opuwo
# Processing Record 46 of Set 9 | morant bay
# Processing Record 47 of Set 9 | moerai
# Processing Record 48 of Set 9 | lyuban
# Processing Record 49 of Set 9 | monrovia
# Processing Record 50 of Set 9 | saint-francois
# Processing Record 1 of Set 10 | monze
# Processing Record 2 of Set 10 | waspan
# Processing Record 3 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 10 | ilulissat
# Processing Record 5 of Set 10 | payo
# Processing Record 6 of Set 10 | grand gaube
# Processing Record 7 of Set 10 | magnitogorsk
# Processing Record 8 of Set 10 | payson
# Processing Record 9 of Set 10 | coquimbo
# Processing Record 10 of Set 10 | codajas
# Processing Record 11 of Set 10 | fort nelson
# Processing Record 12 of Set 10 | celica
# Processing Record 13 of Set 10 | ebbw vale
# Processing Record 14 of Set 10 | rabo de peixe
# Processing Record 15 of Set 10 | tiarei
# Processing Record 16 of Set 10 | biloela
# Processing Record 17 of Set 10 | dawlatabad
# Processing Record 18 of Set 10 | teyateyaneng
# Processing Record 19 of Set 10 | padang
# Processing Record 20 of Set 10 | myitkyina
# Processing Record 21 of Set 10 | kenitra
# Processing Record 22 of Set 10 | porto novo
# Processing Record 23 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 24 of Set 10 | haimen
# Processing Record 25 of Set 10 | la macarena
# Processing Record 26 of Set 10 | husavik
# Processing Record 27 of Set 10 | bethanien
# Processing Record 28 of Set 10 | kutum
# Processing Record 29 of Set 10 | kununurra
# Processing Record 30 of Set 10 | timiryazevskiy
# Processing Record 31 of Set 10 | kysyl-syr
# Processing Record 32 of Set 10 | kailua
# Processing Record 33 of Set 10 | katsuura
# Processing Record 34 of Set 10 | belle fourche
# Processing Record 35 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 36 of Set 10 | acarau
# Processing Record 37 of Set 10 | synya
# Processing Record 38 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 10 | kidal
# Processing Record 40 of Set 10 | tarauaca
# Processing Record 41 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 10 | takoradi
# Processing Record 43 of Set 10 | altdorf
# Processing Record 44 of Set 10 | havelock
# Processing Record 45 of Set 10 | illapel
# Processing Record 46 of Set 10 | biak
# Processing Record 47 of Set 10 | thinadhoo
# Processing Record 48 of Set 10 | rio grande
# Processing Record 49 of Set 10 | krasnovishersk
# Processing Record 50 of Set 10 | northam
# Processing Record 1 of Set 11 | merauke
# Processing Record 2 of Set 11 | aklavik
# Processing Record 3 of Set 11 | pangoa
# Processing Record 4 of Set 11 | maarianhamina
# Processing Record 5 of Set 11 | maues
# Processing Record 6 of Set 11 | vuktyl
# Processing Record 7 of Set 11 | gushikawa
# Processing Record 8 of Set 11 | sorong
# Processing Record 9 of Set 11 | iqaluit
# Processing Record 10 of Set 11 | vanavara
# Processing Record 11 of Set 11 | sancti spiritus
# Processing Record 12 of Set 11 | puerto boyaca
# Processing Record 13 of Set 11 | luangwa
# Processing Record 14 of Set 11 | fortuna foothills
# Processing Record 15 of Set 11 | egvekinot
# Processing Record 16 of Set 11 | aginskoye
# Processing Record 17 of Set 11 | bela
# Processing Record 18 of Set 11 | san cristobal
# Processing Record 19 of Set 11 | carballo
# Processing Record 20 of Set 11 | poum
# Processing Record 21 of Set 11 | saint-ambroise
# Processing Record 22 of Set 11 | shelburne
# Processing Record 23 of Set 11 | key biscayne
# Processing Record 24 of Set 11 | port antonio
# Processing Record 25 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 26 of Set 11 | naron
# Processing Record 27 of Set 11 | kirakira
# Processing Record 28 of Set 11 | kourou
# Processing Record 29 of Set 11 | pemangkat
# Processing Record 30 of Set 11 | san patricio
# Processing Record 31 of Set 11 | fairbanks
# Processing Record 32 of Set 11 | raudeberg
# Processing Record 33 of Set 11 | los llanos de aridane
# Processing Record 34 of Set 11 | shiyan
# Processing Record 35 of Set 11 | kedrovyy
# Processing Record 36 of Set 11 | aksha
# Processing Record 37 of Set 11 | saint-augustin
# Processing Record 38 of Set 11 | chiredzi
# Processing Record 39 of Set 11 | nouakchott
# Processing Record 40 of Set 11 | teneguiban
# City not found. Skipping...
# Processing Record 41 of Set 11 | araouane
# Processing Record 42 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 11 | marchtrenk
# Processing Record 44 of Set 11 | namibe
# Processing Record 45 of Set 11 | faya
# Processing Record 46 of Set 11 | comodoro rivadavia
# Processing Record 47 of Set 11 | banyo
# Processing Record 48 of Set 11 | dunkwa
# Processing Record 49 of Set 11 | caranavi
# Processing Record 50 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 12 | machilipatnam
# Processing Record 2 of Set 12 | lincoln
# Processing Record 3 of Set 12 | nkhotakota
# Processing Record 4 of Set 12 | nigde
# Processing Record 5 of Set 12 | dolinsk
# Processing Record 6 of Set 12 | guerrero negro
# Processing Record 7 of Set 12 | silivri
# Processing Record 8 of Set 12 | bembereke
# Processing Record 9 of Set 12 | kuala terengganu
# Processing Record 10 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 12 | alekseyevka
# Processing Record 12 of Set 12 | durango
# Processing Record 13 of Set 12 | port blair
# Processing Record 14 of Set 12 | saint-paul
# Processing Record 15 of Set 12 | marsa matruh
# Processing Record 16 of Set 12 | verkhnevilyuysk
# Processing Record 17 of Set 12 | dandong
# Processing Record 18 of Set 12 | astakos
# Processing Record 19 of Set 12 | balkanabat
# Processing Record 20 of Set 12 | juazeiro
# Processing Record 21 of Set 12 | chulman
# Processing Record 22 of Set 12 | dinguiraye
# Processing Record 23 of Set 12 | guayaramerin
# Processing Record 24 of Set 12 | kavaratti
# Processing Record 25 of Set 12 | urusha
# Processing Record 26 of Set 12 | perumpavur
# Processing Record 27 of Set 12 | moose factory
# Processing Record 28 of Set 12 | marienburg
# Processing Record 29 of Set 12 | bria
# Processing Record 30 of Set 12 | brigantine
# Processing Record 31 of Set 12 | waipawa
# Processing Record 32 of Set 12 | nhulunbuy
# Processing Record 33 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 34 of Set 12 | bandarbeyla
# Processing Record 35 of Set 12 | huarmey
# Processing Record 36 of Set 12 | bartica
# Processing Record 37 of Set 12 | kosh-agach
# Processing Record 38 of Set 12 | fenoarivo
# Processing Record 39 of Set 12 | madinat sittah uktubar
# Processing Record 40 of Set 12 | bam
# Processing Record 41 of Set 12 | humberto de campos
# Processing Record 42 of Set 12 | puri
# Processing Record 43 of Set 12 | zavitinsk
# Processing Record 44 of Set 12 | santa isabel do rio negro
# Processing Record 45 of Set 12 | imbituba
# Processing Record 46 of Set 12 | nara
# Processing Record 47 of Set 12 | roebourne
# Processing Record 48 of Set 12 | doctor juan leon mallorquin
# Processing Record 49 of Set 12 | bella union
# Processing Record 50 of Set 12 | north bend
# Processing Record 1 of Set 13 | kasongo
# Processing Record 2 of Set 13 | lufilufi
# Processing Record 3 of Set 13 | jeremie
# Processing Record 4 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 13 | altay
# Processing Record 6 of Set 13 | harbour breton
# Processing Record 7 of Set 13 | pontianak
# Processing Record 8 of Set 13 | lavrentiya
# Processing Record 9 of Set 13 | bekovo
# Processing Record 10 of Set 13 | port-gentil
# Processing Record 11 of Set 13 | jutai
# Processing Record 12 of Set 13 | norsup
# Processing Record 13 of Set 13 | penzance
# Processing Record 14 of Set 13 | northport
# Processing Record 15 of Set 13 | farafangana
# Processing Record 16 of Set 13 | puerto escondido
# Processing Record 17 of Set 13 | pacific grove
# Processing Record 18 of Set 13 | treinta y tres
# Processing Record 19 of Set 13 | touros
# Processing Record 20 of Set 13 | najran
# Processing Record 21 of Set 13 | vilyuysk
# Processing Record 22 of Set 13 | mago
# Processing Record 23 of Set 13 | maracana
# Processing Record 24 of Set 13 | yatou
# Processing Record 25 of Set 13 | te anau
# Processing Record 26 of Set 13 | tokur
# Processing Record 27 of Set 13 | encantado
# Processing Record 28 of Set 13 | yevlax
# Processing Record 29 of Set 13 | maymyo
# Processing Record 30 of Set 13 | saint anthony
# Processing Record 31 of Set 13 | chingirlau
# Processing Record 32 of Set 13 | noumea
# Processing Record 33 of Set 13 | fukue
# Processing Record 34 of Set 13 | flagstaff
# Processing Record 35 of Set 13 | walvis bay
# Processing Record 36 of Set 13 | maldonado
# Processing Record 37 of Set 13 | kemijarvi
# Processing Record 38 of Set 13 | redlands
# Processing Record 39 of Set 13 | macamic
# Processing Record 40 of Set 13 | huanren
# Processing Record 41 of Set 13 | lichinga
# Processing Record 42 of Set 13 | palu
# Processing Record 43 of Set 13 | carutapera
# Processing Record 44 of Set 13 | dryden
# Processing Record 45 of Set 13 | sept-iles
# Processing Record 46 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 13 | isiro
# Processing Record 48 of Set 13 | barcelona
# Processing Record 49 of Set 13 | baykit
# Processing Record 50 of Set 13 | macedo de cavaleiros
# Processing Record 1 of Set 14 | kathu
# Processing Record 2 of Set 14 | vidim
# Processing Record 3 of Set 14 | ploemeur
# Processing Record 4 of Set 14 | marakkanam
# Processing Record 5 of Set 14 | barranquilla
# Processing Record 6 of Set 14 | rossano
# Processing Record 7 of Set 14 | maniitsoq
# Processing Record 8 of Set 14 | daura
# Processing Record 9 of Set 14 | vrangel
# Processing Record 10 of Set 14 | bedesa
# Processing Record 11 of Set 14 | manggar
# Processing Record 12 of Set 14 | jardim
# Processing Record 13 of Set 14 | tual
# Processing Record 14 of Set 14 | porto santo
# Processing Record 15 of Set 14 | buin
# Processing Record 16 of Set 14 | mitzic
# Processing Record 17 of Set 14 | kurilsk
# Processing Record 18 of Set 14 | rocha
# Processing Record 19 of Set 14 | marang
# Processing Record 20 of Set 14 | bronnoysund
# Processing Record 21 of Set 14 | cayenne
# Processing Record 22 of Set 14 | seoul
# Processing Record 23 of Set 14 | sorland
# Processing Record 24 of Set 14 | qianguo
# Processing Record 25 of Set 14 | maragogi
# Processing Record 26 of Set 14 | batticaloa
# Processing Record 27 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 14 | staryy nadym
# Processing Record 29 of Set 14 | alexandria
# Processing Record 30 of Set 14 | san giuseppe jato
# Processing Record 31 of Set 14 | kattivakkam
# Processing Record 32 of Set 14 | palmer
# Processing Record 33 of Set 14 | deputatskiy
# Processing Record 34 of Set 14 | okha
# Processing Record 35 of Set 14 | longyearbyen
# Processing Record 36 of Set 14 | cockburn town
# Processing Record 37 of Set 14 | bowen
# Processing Record 38 of Set 14 | hami
# Processing Record 39 of Set 14 | babu
# Processing Record 40 of Set 14 | sunrise
# Processing Record 41 of Set 14 | talara
# Processing Record 42 of Set 14 | chattanooga
# Processing Record 43 of Set 14 | san policarpo
# Processing Record 44 of Set 14 | marsh harbour
# Processing Record 45 of Set 14 | codrington
# Processing Record 46 of Set 14 | sistranda
# Processing Record 47 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 14 | sioux lookout
# Processing Record 49 of Set 14 | lere
# Processing Record 50 of Set 14 | pringsewu
# Processing Record 1 of Set 15 | snasa
# Processing Record 2 of Set 15 | sheltozero
# Processing Record 3 of Set 15 | havre-saint-pierre
# Processing Record 4 of Set 15 | palmas bellas
# Processing Record 5 of Set 15 | tibati
# Processing Record 6 of Set 15 | longford
# Processing Record 7 of Set 15 | lengshuijiang
# Processing Record 8 of Set 15 | verkhoyansk
# Processing Record 9 of Set 15 | fort morgan
# Processing Record 10 of Set 15 | clonakilty
# Processing Record 11 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 15 | broken hill
# Processing Record 13 of Set 15 | vestmannaeyjar
# Processing Record 14 of Set 15 | broome
# Processing Record 15 of Set 15 | platteville
# Processing Record 16 of Set 15 | chicama
# Processing Record 17 of Set 15 | lampang
# Processing Record 18 of Set 15 | port macquarie
# Processing Record 19 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 20 of Set 15 | pafos
# Processing Record 21 of Set 15 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 22 of Set 15 | victor harbor
# Processing Record 23 of Set 15 | kamaishi
# Processing Record 24 of Set 15 | evensk
# Processing Record 25 of Set 15 | belmonte
# Processing Record 26 of Set 15 | teotitlan
# Processing Record 27 of Set 15 | zorritos
# Processing Record 28 of Set 15 | iwanai
# Processing Record 29 of Set 15 | orlovskiy
# Processing Record 30 of Set 15 | tautira
# Processing Record 31 of Set 15 | tilichiki
# Processing Record 32 of Set 15 | nong kung si
# Processing Record 33 of Set 15 | labuhan
# Processing Record 34 of Set 15 | hervey bay
# Processing Record 35 of Set 15 | gobabis
# Processing Record 36 of Set 15 | itarema
# Processing Record 37 of Set 15 | naze
# Processing Record 38 of Set 15 | blackwater
# Processing Record 39 of Set 15 | coro
# Processing Record 40 of Set 15 | karacabey
# Processing Record 41 of Set 15 | rojhan
# Processing Record 42 of Set 15 | jilmah
# City not found. Skipping...
# Processing Record 43 of Set 15 | romilly-sur-seine
# Processing Record 44 of Set 15 | fengzhen
# Processing Record 45 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 15 | bodden town
# Processing Record 47 of Set 15 | robore
# Processing Record 48 of Set 15 | cam ranh
# Processing Record 49 of Set 15 | pachino
# Processing Record 50 of Set 15 | kariba
# Processing Record 1 of Set 16 | zheleznodorozhnyy
# Processing Record 2 of Set 16 | stornoway
# Processing Record 3 of Set 16 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 16 | ullapool
# Processing Record 5 of Set 16 | madingou
# Processing Record 6 of Set 16 | yuzhou
# Processing Record 7 of Set 16 | lhokseumawe
# Processing Record 8 of Set 16 | polunochnoye
# Processing Record 9 of Set 16 | robertsport
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 704

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Vao      NC -22.6667  167.4833     70.23        65          99
# 1       Carnarvon      AU -24.8667  113.6333     65.59        64           0
# 2            Lamu      KE  -2.2717   40.9020     79.02        77           1
# 3        Thompson      CA  55.7435  -97.8558     60.96        88         100
# 4         Kodinsk      RU  58.6881   99.1844     55.44        89           9
# 5  Ribeira Grande      PT  38.5167  -28.7000     64.76        87          57
# 6            Daru      PG  -9.0763  143.2092     76.95        90         100
# 7          Collie      AU -33.3667  116.1500     54.28        94          88
# 8    Port Hedland      AU -20.3167  118.5667     59.05        67           0
# 9           Reitz      ZA -27.8014   28.4273     44.24        88           0
#
#    Wind Speed Current Description
# 0       15.88     overcast clouds
# 1       11.63           clear sky
# 2       18.16          light rain
# 3       10.36     overcast clouds
# 4        2.91           clear sky
# 5       20.51       broken clouds
# 6       17.78       moderate rain
# 7        3.53     overcast clouds
# 8        8.05           clear sky
# 9        8.23           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Vao      NC -22.6667  167.4833     70.23        65          99
# 1       Carnarvon      AU -24.8667  113.6333     65.59        64           0
# 2            Lamu      KE  -2.2717   40.9020     79.02        77           1
# 3        Thompson      CA  55.7435  -97.8558     60.96        88         100
# 4         Kodinsk      RU  58.6881   99.1844     55.44        89           9
# 5  Ribeira Grande      PT  38.5167  -28.7000     64.76        87          57
# 6            Daru      PG  -9.0763  143.2092     76.95        90         100
# 7          Collie      AU -33.3667  116.1500     54.28        94          88
# 8    Port Hedland      AU -20.3167  118.5667     59.05        67           0
# 9           Reitz      ZA -27.8014   28.4273     44.24        88           0
#
#    Wind Speed Current Description
# 0       15.88     overcast clouds
# 1       11.63           clear sky
# 2       18.16          light rain
# 3       10.36     overcast clouds
# 4        2.91           clear sky
# 5       20.51       broken clouds
# 6       17.78       moderate rain
# 7        3.53     overcast clouds
# 8        8.05           clear sky
# 9        8.23           clear sky

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
